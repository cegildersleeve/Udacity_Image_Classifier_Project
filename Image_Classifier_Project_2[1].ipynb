# %% [markdown]
# # Developing an AI application
#
# Going forward, AI algorithms will be incorporated into more and more everyday applications. For example, you might want to include an image classifier in a smart phone app. To do this, you'd use a deep learning model trained on hundreds of thousands of images as part of the overall application architecture. A large part of software development in the future will be using these types of models as common parts of applications.
#
# In this project, you'll train an image classifier to recognize different species of flowers. You can imagine using something like this in a phone app that tells you the name of the flower your camera is looking at. In practice you'd train this classifier, then export it for use in your application. We'll be using [this dataset](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) of 102 flower categories, you can see a few examples below.
#
# <img src='assets/Flowers.png' width=500px>
#
# The project is broken down into multiple steps:
#
# * Load and preprocess the image dataset
# * Train the image classifier on your dataset
# * Use the trained classifier to predict image content
#
# We'll lead you through each part which you'll implement in Python.
#
# When you've completed this project, you'll have an application that can be trained on any set of labeled images. Here your network will be learning about flowers and end up as a command line application. But, what you do with your new skills depends on your imagination and effort in building a dataset. For example, imagine an app where you take a picture of a car, it tells you what the make and model is, then looks up information about it. Go build your own dataset and make something new.
#
# First up is importing the packages you'll need. It's good practice to keep all the imports at the beginning of your code. As you work through this notebook and find you need to import a package, make sure to add the import up here.

# %%
# Imports here


import workspace_utils
import matplotlib.pyplot as plt
import numpy as np
import torch
from torch import nn
from torch import optim
import torch.nn.functional as F
from torchvision import datasets, transforms, models
import torchvision.models as models
from PIL import Image
import json
from matplotlib.ticker import FormatStrFormatter

# %% [markdown]
# ## Load the data
#
# Here you'll use `torchvision` to load the data ([documentation](http://pytorch.org/docs/0.3.0/torchvision/index.html)). The data should be included alongside this notebook, otherwise you can [download it here](https://s3.amazonaws.com/content.udacity-data.com/nd089/flower_data.tar.gz). The dataset is split into three parts, training, validation, and testing. For the training, you'll want to apply transformations such as random scaling, cropping, and flipping. This will help the network generalize leading to better performance. You'll also need to make sure the input data is resized to 224x224 pixels as required by the pre-trained networks.
#
# The validation and testing sets are used to measure the model's performance on data it hasn't seen yet. For this you don't want any scaling or rotation transformations, but you'll need to resize then crop the images to the appropriate size.
#
# The pre-trained networks you'll use were trained on the ImageNet dataset where each color channel was normalized separately. For all three sets you'll need to normalize the means and standard deviations of the images to what the network expects. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`, calculated from the ImageNet images.  These values will shift each color channel to be centered at 0 and range from -1 to 1.

# %%
data_dir = 'flowers'
train_dir = data_dir + '/train'
valid_dir = data_dir + '/valid'
test_dir = data_dir + '/test'

# %%
# TODO: Define your transforms for the training, validation, and testing sets
train_transforms = transforms.Compose([transforms.RandomRotation(30),
                                       transforms.RandomResizedCrop(224),
                                       transforms.RandomHorizontalFlip(),
                                       transforms.ToTensor(),
                                       transforms.Normalize([0.485, 0.456, 0.406], 
                                                            [0.229, 0.224, 0.225])])

test_transforms = transforms.Compose([transforms.Resize(256),
                                      transforms.CenterCrop(224),
                                      transforms.ToTensor(),
                                      transforms.Normalize([0.485, 0.456, 0.406], 
                                                           [0.229, 0.224, 0.225])])

validation_transforms = transforms.Compose([transforms.Resize(256),
                                            transforms.CenterCrop(224),
                                            transforms.ToTensor(),
                                            transforms.Normalize([0.485, 0.456, 0.406], 
                                                                 [0.229, 0.224, 0.225])])


# TODO: Load the datasets with ImageFolder
train_data = datasets.ImageFolder(train_dir, transform=train_transforms)
validation_data = datasets.ImageFolder(valid_dir, transform=validation_transforms)
test_data = datasets.ImageFolder(test_dir ,transform = test_transforms)

# TODO: Using the image datasets and the trainforms, define the dataloaders
trainloader = torch.utils.data.DataLoader(train_data, batch_size=64, shuffle=True)
vloader = torch.utils.data.DataLoader(validation_data, batch_size =32,shuffle = True)
testloader = torch.utils.data.DataLoader(test_data, batch_size = 20, shuffle = True)

# %%
inputs, labels = next(iter(trainloader))
inputs [0,:]
inputs.size ()
# Out:
# torch.Size([64, 3, 224, 224])

# %% [markdown]
# ### Label mapping
#
# You'll also need to load in a mapping from category label to category name. You can find this in the file `cat_to_name.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/2/library/json.html). This will give you a dictionary mapping the integer encoded categories to the actual names of the flowers.

# %%
with open('cat_to_name.json', 'r') as f:
    cat_to_name = json.load(f)

# %%
cat_to_name
# Out:
# {'21': 'fire lily',
#  '3': 'canterbury bells',
#  '45': 'bolero deep blue',
#  '1': 'pink primrose',
#  '34': 'mexican aster',
#  '27': 'prince of wales feathers',
#  '7': 'moon orchid',
#  '16': 'globe-flower',
#  '25': 'grape hyacinth',
#  '26': 'corn poppy',
#  '79': 'toad lily',
#  '39': 'siam tulip',
#  '24': 'red ginger',
#  '67': 'spring crocus',
#  '35': 'alpine sea holly',
#  '32': 'garden phlox',
#  '10': 'globe thistle',
#  '6': 'tiger lily',
#  '93': 'ball moss',
#  '33': 'love in the mist',
#  '9': 'monkshood',
#  '102': 'blackberry lily',
#  '14': 'spear thistle',
#  '19': 'balloon flower',
#  '100': 'blanket flower',
#  '13': 'king protea',
#  '49': 'oxeye daisy',
#  '15': 'yellow iris',
#  '61': 'cautleya spicata',
#  '31': 'carnation',
#  '64': 'silverbush',
#  '68': 'bearded iris',
#  '63': 'black-eyed susan',
#  '69': 'windflower',
#  '62': 'japanese anemone',
#  '20': 'giant white arum lily',
#  '38': 'great masterwort',
#  '4': 'sweet pea',
#  '86': 'tree mallow',
#  '101': 'trumpet creeper',
#  '42': 'daffodil',
#  '22': 'pincushion flower',
#  '2': 'hard-leaved pocket orchid',
#  '54': 'sunflower',
#  '66': 'osteospermum',
#  '70': 'tree poppy',
#  '85': 'desert-rose',
#  '99': 'bromelia',
#  '87': 'magnolia',
#  '5': 'english marigold',
#  '92': 'bee balm',
#  '28': 'stemless gentian',
#  '97': 'mallow',
#  '57': 'gaura',
#  '40': 'lenten rose',
#  '47': 'marigold',
#  '59': 'orange dahlia',
#  '48': 'buttercup',
#  '55': 'pelargonium',
#  '36': 'ruby-lipped cattleya',
#  '91': 'hippeastrum',
#  '29': 'artichoke',
#  '71': 'gazania',
#  '90': 'canna lily',
#  '18': 'peruvian lily',
#  '98': 'mexican petunia',
#  '8': 'bird of paradise',
#  '30': 'sweet william',
#  '17': 'purple coneflower',
#  '52': 'wild pansy',
#  '84': 'columbine',
#  '12': "colt's foot",
#  '11': 'snapdragon',
#  '96': 'camellia',
#  '23': 'fritillary',
#  '50': 'common dandelion',
#  '44': 'poinsettia',
#  '53': 'primula',
#  '72': 'azalea',
#  '65': 'californian poppy',
#  '80': 'anthurium',
#  '76': 'morning glory',
#  '37': 'cape flower',
#  '56': 'bishop of llandaff',
#  '60': 'pink-yellow dahlia',
#  '82': 'clematis',
#  '58': 'geranium',
#  '75': 'thorn apple',
#  '41': 'barbeton daisy',
#  '95': 'bougainvillea',
#  '43': 'sword lily',
#  '83': 'hibiscus',
#  '78': 'lotus lotus',
#  '88': 'cyclamen',
#  '94': 'foxglove',
#  '81': 'frangipani',
#  '74': 'rose',
#  '89': 'watercress',
#  '73': 'water lily',
#  '46': 'wallflower',
#  '77': 'passion flower',
#  '51': 'petunia'}

# %% [markdown]
# # Building and training the classifier
#
# Now that the data is ready, it's time to build and train the classifier. As usual, you should use one of the pretrained models from `torchvision.models` to get the image features. Build and train a new feed-forward classifier using those features.
#
# We're going to leave this part up to you. Refer to [the rubric](https://review.udacity.com/#!/rubrics/1663/view) for guidance on successfully completing this section. Things you'll need to do:
#
# * Load a [pre-trained network](http://pytorch.org/docs/master/torchvision/models.html) (If you need a starting point, the VGG networks work great and are straightforward to use)
# * Define a new, untrained feed-forward network as a classifier, using ReLU activations and dropout
# * Train the classifier layers using backpropagation using the pre-trained network to get the features
# * Track the loss and accuracy on the validation set to determine the best hyperparameters
#
# We've left a cell open for you below, but use as many as you need. Our advice is to break the problem up into smaller parts you can run separately. Check that each part is doing what you expect, then move on to the next. You'll likely find that as you work through each part, you'll need to go back and modify your previous code. This is totally normal!
#
# When training make sure you're updating only the weights of the feed-forward network. You should be able to get the validation accuracy above 70% if you build everything right. Make sure to try different hyperparameters (learning rate, units in the classifier, epochs, etc) to find the best model. Save those hyperparameters to use as default values in the next part of the project.
#
# One last important tip if you're using the workspace to run your code: To avoid having your workspace disconnect during the long-running tasks in this notebook, please read in the earlier page in this lesson called Intro to
# GPU Workspaces about Keeping Your Session Active. You'll want to include code from the workspace_utils.py module.
#
# **Note for Workspace users:** If your network is over 1 GB when saved as a checkpoint, there might be issues with saving backups in your workspace. Typically this happens with wide dense layers after the convolutional layers. If your saved checkpoint is larger than 1 GB (you can open a terminal and check with `ls -lh`), you should reduce the size of your hidden layers and train again.

# %%
# TODO: Build and train your network

structures = {"vgg16":25088,
              "densenet121" : 1024,
              "alexnet" : 9216 }

# %%
def nn_setup(structure='vgg16',dropout=0.5, hidden_layer1 = 120,lr = 0.001):
    
    
    if structure == 'vgg16':
        model = models.vgg16(pretrained=True)        
    elif structure == 'densenet121':
        model = models.densenet121(pretrained=True)
    elif structure == 'alexnet':
        model = models.alexnet(pretrained = True)
        
    
        
    for param in model.parameters():
        param.requires_grad = False

        from collections import OrderedDict
        classifier = nn.Sequential(OrderedDict([
            ('dropout',nn.Dropout(dropout)),
            ('inputs', nn.Linear(structures[structure], hidden_layer1)),
            ('relu1', nn.ReLU()),
            ('hidden_layer1', nn.Linear(hidden_layer1, 90)),
            ('relu2',nn.ReLU()),
            ('hidden_layer2',nn.Linear(90,80)),
            ('relu3',nn.ReLU()),
            ('hidden_layer3',nn.Linear(80,102)),
            ('output', nn.LogSoftmax(dim=1))
                          ]))
        
        
        model.classifier = classifier
        criterion = nn.NLLLoss()
        optimizer = optim.Adam(model.classifier.parameters(), lr )
        model.cuda()
        
        return model , optimizer ,criterion 

    

model,optimizer,criterion = nn_setup('vgg16')

# %%
epochs = 20
steps = 0
running_loss = 0
print_every = 5

train_losses, valid_losses = [], []

model.to('cuda')

with workspace_utils.active_session():

    for epoch in range(epochs):
        for inputs, labels in trainloader:
            steps += 1
            inputs, labels = inputs.to('cuda'), labels.to('cuda')
            optimizer.zero_grad()
        
            logps = model.forward(inputs)
            loss = criterion(logps, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
        
            if steps % print_every == 0:
                valid_loss = 0
                accuracy = 0
                model.eval()
                with torch.no_grad():
                    for inputs, labels in vloader:
                        inputs, labels = inputs.to('cuda'), labels.to('cuda')
                        logps = model.forward(inputs)
                        batch_loss = criterion(logps, labels)
                    
                        valid_loss += batch_loss.item()
                    
                        # Calculate accuracy
                        ps = torch.exp(logps)
                        top_p, top_class = ps.topk(1, dim=1)
                        equals = top_class == labels.view(*top_class.shape)
                        accuracy += torch.mean(equals.type(torch.FloatTensor)).item()
                    
                    
                train_losses.append(running_loss/len(trainloader))
                valid_losses.append(valid_loss/len(vloader))
            
                print(f"Epoch {epoch+1}/{epochs}.. "
                      f"Train loss: {running_loss/print_every:.3f}.. "
                      f"Valid loss: {valid_loss/len(vloader):.3f}.. "
                      f"Valid accuracy: {accuracy/len(vloader):.3f}")
                running_loss = 0
                model.train()
# Out:
# Epoch 1/20.. Train loss: 4.616.. Valid loss: 4.574.. Valid accuracy: 0.032
# Epoch 1/20.. Train loss: 4.544.. Valid loss: 4.441.. Valid accuracy: 0.069
# Epoch 1/20.. Train loss: 4.447.. Valid loss: 4.327.. Valid accuracy: 0.064
# Epoch 1/20.. Train loss: 4.379.. Valid loss: 4.202.. Valid accuracy: 0.094
# Epoch 1/20.. Train loss: 4.257.. Valid loss: 4.018.. Valid accuracy: 0.122
# Epoch 1/20.. Train loss: 4.225.. Valid loss: 3.815.. Valid accuracy: 0.205
# Epoch 1/20.. Train loss: 3.900.. Valid loss: 3.615.. Valid accuracy: 0.173
# Epoch 1/20.. Train loss: 3.797.. Valid loss: 3.440.. Valid accuracy: 0.222
# Epoch 1/20.. Train loss: 3.713.. Valid loss: 3.182.. Valid accuracy: 0.253
# Epoch 1/20.. Train loss: 3.329.. Valid loss: 3.052.. Valid accuracy: 0.274
# Epoch 1/20.. Train loss: 3.274.. Valid loss: 2.792.. Valid accuracy: 0.360
# Epoch 1/20.. Train loss: 3.096.. Valid loss: 2.584.. Valid accuracy: 0.401
# Epoch 1/20.. Train loss: 2.973.. Valid loss: 2.445.. Valid accuracy: 0.422
# Epoch 1/20.. Train loss: 2.836.. Valid loss: 2.413.. Valid accuracy: 0.390
# Epoch 1/20.. Train loss: 2.834.. Valid loss: 2.151.. Valid accuracy: 0.470
# Epoch 1/20.. Train loss: 2.578.. Valid loss: 2.105.. Valid accuracy: 0.471
# Epoch 1/20.. Train loss: 2.456.. Valid loss: 1.913.. Valid accuracy: 0.503
# Epoch 1/20.. Train loss: 2.471.. Valid loss: 1.865.. Valid accuracy: 0.512
# Epoch 1/20.. Train loss: 2.295.. Valid loss: 1.687.. Valid accuracy: 0.533
# Epoch 1/20.. Train loss: 2.218.. Valid loss: 1.685.. Valid accuracy: 0.542
# Epoch 2/20.. Train loss: 2.155.. Valid loss: 1.648.. Valid accuracy: 0.584
# Epoch 2/20.. Train loss: 2.058.. Valid loss: 1.518.. Valid accuracy: 0.611
# Epoch 2/20.. Train loss: 1.993.. Valid loss: 1.556.. Valid accuracy: 0.587
# Epoch 2/20.. Train loss: 2.111.. Valid loss: 1.457.. Valid accuracy: 0.577
# Epoch 2/20.. Train loss: 1.949.. Valid loss: 1.457.. Valid accuracy: 0.595
# Epoch 2/20.. Train loss: 1.824.. Valid loss: 1.523.. Valid accuracy: 0.594
# Epoch 2/20.. Train loss: 1.773.. Valid loss: 1.409.. Valid accuracy: 0.611
# Epoch 2/20.. Train loss: 1.692.. Valid loss: 1.292.. Valid accuracy: 0.644
# Epoch 2/20.. Train loss: 1.569.. Valid loss: 1.464.. Valid accuracy: 0.608
# Epoch 2/20.. Train loss: 1.976.. Valid loss: 1.204.. Valid accuracy: 0.671
# Epoch 2/20.. Train loss: 1.666.. Valid loss: 1.222.. Valid accuracy: 0.661
# Epoch 2/20.. Train loss: 1.564.. Valid loss: 1.282.. Valid accuracy: 0.646
# Epoch 2/20.. Train loss: 1.657.. Valid loss: 1.226.. Valid accuracy: 0.658
# Epoch 2/20.. Train loss: 1.697.. Valid loss: 1.121.. Valid accuracy: 0.707
# Epoch 2/20.. Train loss: 1.560.. Valid loss: 1.122.. Valid accuracy: 0.698
# Epoch 2/20.. Train loss: 1.422.. Valid loss: 1.005.. Valid accuracy: 0.714
# Epoch 2/20.. Train loss: 1.495.. Valid loss: 1.014.. Valid accuracy: 0.700
# Epoch 2/20.. Train loss: 1.596.. Valid loss: 1.069.. Valid accuracy: 0.706
# Epoch 2/20.. Train loss: 1.540.. Valid loss: 1.035.. Valid accuracy: 0.707
# Epoch 2/20.. Train loss: 1.652.. Valid loss: 1.013.. Valid accuracy: 0.716
# Epoch 2/20.. Train loss: 1.498.. Valid loss: 1.085.. Valid accuracy: 0.668
# Epoch 3/20.. Train loss: 1.501.. Valid loss: 1.003.. Valid accuracy: 0.716
# Epoch 3/20.. Train loss: 1.454.. Valid loss: 0.984.. Valid accuracy: 0.721
# Epoch 3/20.. Train loss: 1.426.. Valid loss: 0.976.. Valid accuracy: 0.719
# Epoch 3/20.. Train loss: 1.316.. Valid loss: 0.939.. Valid accuracy: 0.725
# Epoch 3/20.. Train loss: 1.488.. Valid loss: 0.885.. Valid accuracy: 0.740
# Epoch 3/20.. Train loss: 1.438.. Valid loss: 0.918.. Valid accuracy: 0.725
# Epoch 3/20.. Train loss: 1.549.. Valid loss: 0.892.. Valid accuracy: 0.748
# Epoch 3/20.. Train loss: 1.425.. Valid loss: 0.933.. Valid accuracy: 0.744
# Epoch 3/20.. Train loss: 1.454.. Valid loss: 0.929.. Valid accuracy: 0.722
# Epoch 3/20.. Train loss: 1.369.. Valid loss: 0.868.. Valid accuracy: 0.729
# Epoch 3/20.. Train loss: 1.315.. Valid loss: 0.852.. Valid accuracy: 0.756
# Epoch 3/20.. Train loss: 1.277.. Valid loss: 0.915.. Valid accuracy: 0.735
# Epoch 3/20.. Train loss: 1.236.. Valid loss: 0.821.. Valid accuracy: 0.757
# Epoch 3/20.. Train loss: 1.341.. Valid loss: 0.836.. Valid accuracy: 0.765
# Epoch 3/20.. Train loss: 1.181.. Valid loss: 0.795.. Valid accuracy: 0.785
# Epoch 3/20.. Train loss: 1.176.. Valid loss: 0.788.. Valid accuracy: 0.796
# Epoch 3/20.. Train loss: 1.247.. Valid loss: 0.798.. Valid accuracy: 0.775
# Epoch 3/20.. Train loss: 1.145.. Valid loss: 0.811.. Valid accuracy: 0.765
# Epoch 3/20.. Train loss: 1.216.. Valid loss: 0.783.. Valid accuracy: 0.776
# Epoch 3/20.. Train loss: 1.221.. Valid loss: 0.713.. Valid accuracy: 0.796
# Epoch 4/20.. Train loss: 1.192.. Valid loss: 0.808.. Valid accuracy: 0.761
# Epoch 4/20.. Train loss: 1.265.. Valid loss: 0.837.. Valid accuracy: 0.755
# Epoch 4/20.. Train loss: 1.158.. Valid loss: 0.753.. Valid accuracy: 0.768
# Epoch 4/20.. Train loss: 1.139.. Valid loss: 0.733.. Valid accuracy: 0.788
# Epoch 4/20.. Train loss: 1.204.. Valid loss: 0.707.. Valid accuracy: 0.802
# Epoch 4/20.. Train loss: 1.065.. Valid loss: 0.695.. Valid accuracy: 0.786
# Epoch 4/20.. Train loss: 1.203.. Valid loss: 0.771.. Valid accuracy: 0.778
# Epoch 4/20.. Train loss: 1.235.. Valid loss: 0.802.. Valid accuracy: 0.762
# Epoch 4/20.. Train loss: 1.284.. Valid loss: 0.709.. Valid accuracy: 0.791
# Epoch 4/20.. Train loss: 1.036.. Valid loss: 0.675.. Valid accuracy: 0.799
# Epoch 4/20.. Train loss: 1.201.. Valid loss: 0.743.. Valid accuracy: 0.786
# Epoch 4/20.. Train loss: 1.222.. Valid loss: 0.694.. Valid accuracy: 0.798
# Epoch 4/20.. Train loss: 1.092.. Valid loss: 0.748.. Valid accuracy: 0.780
# Epoch 4/20.. Train loss: 1.235.. Valid loss: 0.755.. Valid accuracy: 0.788
# Epoch 4/20.. Train loss: 1.167.. Valid loss: 0.704.. Valid accuracy: 0.796
# Epoch 4/20.. Train loss: 1.169.. Valid loss: 0.753.. Valid accuracy: 0.784
# Epoch 4/20.. Train loss: 1.220.. Valid loss: 0.751.. Valid accuracy: 0.795
# Epoch 4/20.. Train loss: 1.178.. Valid loss: 0.748.. Valid accuracy: 0.789
# Epoch 4/20.. Train loss: 1.207.. Valid loss: 0.647.. Valid accuracy: 0.811
# Epoch 4/20.. Train loss: 0.906.. Valid loss: 0.743.. Valid accuracy: 0.782
# Epoch 4/20.. Train loss: 1.046.. Valid loss: 0.665.. Valid accuracy: 0.805
# Epoch 5/20.. Train loss: 1.020.. Valid loss: 0.711.. Valid accuracy: 0.813
# Epoch 5/20.. Train loss: 1.056.. Valid loss: 0.681.. Valid accuracy: 0.801
# Epoch 5/20.. Train loss: 0.966.. Valid loss: 0.730.. Valid accuracy: 0.792
# Epoch 5/20.. Train loss: 1.066.. Valid loss: 0.718.. Valid accuracy: 0.795
# Epoch 5/20.. Train loss: 1.141.. Valid loss: 0.711.. Valid accuracy: 0.814
# Epoch 5/20.. Train loss: 1.130.. Valid loss: 0.665.. Valid accuracy: 0.800
# Epoch 5/20.. Train loss: 1.036.. Valid loss: 0.679.. Valid accuracy: 0.807
# Epoch 5/20.. Train loss: 1.065.. Valid loss: 0.733.. Valid accuracy: 0.810
# Epoch 5/20.. Train loss: 1.238.. Valid loss: 0.669.. Valid accuracy: 0.831
# Epoch 5/20.. Train loss: 0.985.. Valid loss: 0.654.. Valid accuracy: 0.819
# Epoch 5/20.. Train loss: 1.063.. Valid loss: 0.639.. Valid accuracy: 0.836
# Epoch 5/20.. Train loss: 1.051.. Valid loss: 0.645.. Valid accuracy: 0.839
# Epoch 5/20.. Train loss: 0.947.. Valid loss: 0.681.. Valid accuracy: 0.819
# Epoch 5/20.. Train loss: 1.062.. Valid loss: 0.697.. Valid accuracy: 0.815
# Epoch 5/20.. Train loss: 1.050.. Valid loss: 0.660.. Valid accuracy: 0.831
# Epoch 5/20.. Train loss: 1.094.. Valid loss: 0.656.. Valid accuracy: 0.823
# Epoch 5/20.. Train loss: 1.149.. Valid loss: 0.613.. Valid accuracy: 0.823
# Epoch 5/20.. Train loss: 0.878.. Valid loss: 0.586.. Valid accuracy: 0.851
# Epoch 5/20.. Train loss: 1.062.. Valid loss: 0.615.. Valid accuracy: 0.851
# Epoch 5/20.. Train loss: 1.084.. Valid loss: 0.609.. Valid accuracy: 0.840
# Epoch 5/20.. Train loss: 0.959.. Valid loss: 0.610.. Valid accuracy: 0.817
# Epoch 6/20.. Train loss: 0.761.. Valid loss: 0.673.. Valid accuracy: 0.807
# Epoch 6/20.. Train loss: 0.932.. Valid loss: 0.632.. Valid accuracy: 0.827
# Epoch 6/20.. Train loss: 0.889.. Valid loss: 0.612.. Valid accuracy: 0.832
# Epoch 6/20.. Train loss: 0.940.. Valid loss: 0.575.. Valid accuracy: 0.851
# Epoch 6/20.. Train loss: 1.004.. Valid loss: 0.600.. Valid accuracy: 0.843
# Epoch 6/20.. Train loss: 1.040.. Valid loss: 0.591.. Valid accuracy: 0.846
# Epoch 6/20.. Train loss: 1.017.. Valid loss: 0.578.. Valid accuracy: 0.855
# Epoch 6/20.. Train loss: 1.099.. Valid loss: 0.631.. Valid accuracy: 0.844
# Epoch 6/20.. Train loss: 0.947.. Valid loss: 0.615.. Valid accuracy: 0.834
# Epoch 6/20.. Train loss: 0.870.. Valid loss: 0.634.. Valid accuracy: 0.825
# Epoch 6/20.. Train loss: 0.816.. Valid loss: 0.603.. Valid accuracy: 0.838
# Epoch 6/20.. Train loss: 0.953.. Valid loss: 0.584.. Valid accuracy: 0.840
# Epoch 6/20.. Train loss: 0.845.. Valid loss: 0.583.. Valid accuracy: 0.836
# Epoch 6/20.. Train loss: 1.023.. Valid loss: 0.637.. Valid accuracy: 0.816
# Epoch 6/20.. Train loss: 1.016.. Valid loss: 0.608.. Valid accuracy: 0.824
# Epoch 6/20.. Train loss: 1.086.. Valid loss: 0.565.. Valid accuracy: 0.835
# Epoch 6/20.. Train loss: 1.005.. Valid loss: 0.563.. Valid accuracy: 0.847
# Epoch 6/20.. Train loss: 0.868.. Valid loss: 0.572.. Valid accuracy: 0.850
# Epoch 6/20.. Train loss: 1.020.. Valid loss: 0.606.. Valid accuracy: 0.835
# Epoch 6/20.. Train loss: 0.944.. Valid loss: 0.605.. Valid accuracy: 0.825
# Epoch 7/20.. Train loss: 0.895.. Valid loss: 0.574.. Valid accuracy: 0.828
# Epoch 7/20.. Train loss: 0.859.. Valid loss: 0.611.. Valid accuracy: 0.833
# Epoch 7/20.. Train loss: 0.916.. Valid loss: 0.597.. Valid accuracy: 0.826
# Epoch 7/20.. Train loss: 0.909.. Valid loss: 0.560.. Valid accuracy: 0.842
# Epoch 7/20.. Train loss: 0.880.. Valid loss: 0.541.. Valid accuracy: 0.846
# Epoch 7/20.. Train loss: 0.747.. Valid loss: 0.539.. Valid accuracy: 0.845
# Epoch 7/20.. Train loss: 1.003.. Valid loss: 0.565.. Valid accuracy: 0.835
# Epoch 7/20.. Train loss: 0.803.. Valid loss: 0.523.. Valid accuracy: 0.857
# Epoch 7/20.. Train loss: 0.817.. Valid loss: 0.524.. Valid accuracy: 0.850
# Epoch 7/20.. Train loss: 0.847.. Valid loss: 0.555.. Valid accuracy: 0.866
# Epoch 7/20.. Train loss: 0.769.. Valid loss: 0.585.. Valid accuracy: 0.851
# Epoch 7/20.. Train loss: 0.959.. Valid loss: 0.540.. Valid accuracy: 0.861
# Epoch 7/20.. Train loss: 1.124.. Valid loss: 0.503.. Valid accuracy: 0.871
# Epoch 7/20.. Train loss: 0.982.. Valid loss: 0.488.. Valid accuracy: 0.876
# Epoch 7/20.. Train loss: 0.882.. Valid loss: 0.516.. Valid accuracy: 0.863
# Epoch 7/20.. Train loss: 0.895.. Valid loss: 0.536.. Valid accuracy: 0.859
# Epoch 7/20.. Train loss: 0.746.. Valid loss: 0.560.. Valid accuracy: 0.850
# Epoch 7/20.. Train loss: 0.884.. Valid loss: 0.516.. Valid accuracy: 0.852
# Epoch 7/20.. Train loss: 0.898.. Valid loss: 0.553.. Valid accuracy: 0.848
# Epoch 7/20.. Train loss: 1.110.. Valid loss: 0.574.. Valid accuracy: 0.862
# Epoch 7/20.. Train loss: 1.032.. Valid loss: 0.542.. Valid accuracy: 0.854
# Epoch 8/20.. Train loss: 1.089.. Valid loss: 0.563.. Valid accuracy: 0.828
# Epoch 8/20.. Train loss: 0.943.. Valid loss: 0.554.. Valid accuracy: 0.845
# Epoch 8/20.. Train loss: 1.039.. Valid loss: 0.557.. Valid accuracy: 0.845
# Epoch 8/20.. Train loss: 0.894.. Valid loss: 0.531.. Valid accuracy: 0.861
# Epoch 8/20.. Train loss: 0.853.. Valid loss: 0.528.. Valid accuracy: 0.855
# Epoch 8/20.. Train loss: 1.012.. Valid loss: 0.518.. Valid accuracy: 0.852
# Epoch 8/20.. Train loss: 0.941.. Valid loss: 0.607.. Valid accuracy: 0.844
# Epoch 8/20.. Train loss: 0.936.. Valid loss: 0.546.. Valid accuracy: 0.852
# Epoch 8/20.. Train loss: 0.889.. Valid loss: 0.524.. Valid accuracy: 0.854
# Epoch 8/20.. Train loss: 0.884.. Valid loss: 0.534.. Valid accuracy: 0.839
# Epoch 8/20.. Train loss: 0.844.. Valid loss: 0.571.. Valid accuracy: 0.847
# Epoch 8/20.. Train loss: 0.862.. Valid loss: 0.546.. Valid accuracy: 0.858
# Epoch 8/20.. Train loss: 0.800.. Valid loss: 0.545.. Valid accuracy: 0.851
# Epoch 8/20.. Train loss: 0.976.. Valid loss: 0.502.. Valid accuracy: 0.849
# Epoch 8/20.. Train loss: 0.816.. Valid loss: 0.554.. Valid accuracy: 0.837
# Epoch 8/20.. Train loss: 0.744.. Valid loss: 0.648.. Valid accuracy: 0.804
# Epoch 8/20.. Train loss: 0.963.. Valid loss: 0.548.. Valid accuracy: 0.839
# Epoch 8/20.. Train loss: 0.802.. Valid loss: 0.573.. Valid accuracy: 0.841
# Epoch 8/20.. Train loss: 0.872.. Valid loss: 0.540.. Valid accuracy: 0.849
# Epoch 8/20.. Train loss: 0.853.. Valid loss: 0.473.. Valid accuracy: 0.882
# Epoch 9/20.. Train loss: 0.930.. Valid loss: 0.510.. Valid accuracy: 0.855
# Epoch 9/20.. Train loss: 0.883.. Valid loss: 0.496.. Valid accuracy: 0.863
# Epoch 9/20.. Train loss: 0.841.. Valid loss: 0.451.. Valid accuracy: 0.876
# Epoch 9/20.. Train loss: 0.724.. Valid loss: 0.530.. Valid accuracy: 0.850
# Epoch 9/20.. Train loss: 0.933.. Valid loss: 0.535.. Valid accuracy: 0.855
# Epoch 9/20.. Train loss: 0.805.. Valid loss: 0.489.. Valid accuracy: 0.864
# Epoch 9/20.. Train loss: 0.887.. Valid loss: 0.478.. Valid accuracy: 0.872
# Epoch 9/20.. Train loss: 0.786.. Valid loss: 0.472.. Valid accuracy: 0.876
# Epoch 9/20.. Train loss: 0.772.. Valid loss: 0.492.. Valid accuracy: 0.859
# Epoch 9/20.. Train loss: 0.863.. Valid loss: 0.518.. Valid accuracy: 0.853
# Epoch 9/20.. Train loss: 0.814.. Valid loss: 0.480.. Valid accuracy: 0.868
# Epoch 9/20.. Train loss: 0.841.. Valid loss: 0.518.. Valid accuracy: 0.858
# Epoch 9/20.. Train loss: 0.975.. Valid loss: 0.556.. Valid accuracy: 0.826
# Epoch 9/20.. Train loss: 0.970.. Valid loss: 0.542.. Valid accuracy: 0.851
# Epoch 9/20.. Train loss: 0.729.. Valid loss: 0.536.. Valid accuracy: 0.849
# Epoch 9/20.. Train loss: 0.821.. Valid loss: 0.532.. Valid accuracy: 0.850
# Epoch 9/20.. Train loss: 0.844.. Valid loss: 0.527.. Valid accuracy: 0.859
# Epoch 9/20.. Train loss: 0.787.. Valid loss: 0.564.. Valid accuracy: 0.851
# Epoch 9/20.. Train loss: 0.942.. Valid loss: 0.540.. Valid accuracy: 0.843
# Epoch 9/20.. Train loss: 0.910.. Valid loss: 0.531.. Valid accuracy: 0.846
# Epoch 9/20.. Train loss: 0.743.. Valid loss: 0.508.. Valid accuracy: 0.861
# Epoch 10/20.. Train loss: 0.761.. Valid loss: 0.469.. Valid accuracy: 0.864
# Epoch 10/20.. Train loss: 0.629.. Valid loss: 0.473.. Valid accuracy: 0.859
# Epoch 10/20.. Train loss: 0.796.. Valid loss: 0.482.. Valid accuracy: 0.866
# Epoch 10/20.. Train loss: 0.820.. Valid loss: 0.456.. Valid accuracy: 0.871
# Epoch 10/20.. Train loss: 0.674.. Valid loss: 0.454.. Valid accuracy: 0.869
# Epoch 10/20.. Train loss: 0.679.. Valid loss: 0.505.. Valid accuracy: 0.855
# Epoch 10/20.. Train loss: 0.806.. Valid loss: 0.502.. Valid accuracy: 0.858
# Epoch 10/20.. Train loss: 0.728.. Valid loss: 0.509.. Valid accuracy: 0.858
# Epoch 10/20.. Train loss: 0.817.. Valid loss: 0.507.. Valid accuracy: 0.861
# Epoch 10/20.. Train loss: 0.813.. Valid loss: 0.464.. Valid accuracy: 0.863
# Epoch 10/20.. Train loss: 0.919.. Valid loss: 0.500.. Valid accuracy: 0.862
# Epoch 10/20.. Train loss: 0.724.. Valid loss: 0.501.. Valid accuracy: 0.861
# Epoch 10/20.. Train loss: 0.872.. Valid loss: 0.547.. Valid accuracy: 0.846
# Epoch 10/20.. Train loss: 0.804.. Valid loss: 0.533.. Valid accuracy: 0.856
# Epoch 10/20.. Train loss: 0.837.. Valid loss: 0.482.. Valid accuracy: 0.876
# Epoch 10/20.. Train loss: 0.904.. Valid loss: 0.494.. Valid accuracy: 0.862
# Epoch 10/20.. Train loss: 0.741.. Valid loss: 0.477.. Valid accuracy: 0.871
# Epoch 10/20.. Train loss: 0.789.. Valid loss: 0.453.. Valid accuracy: 0.866
# Epoch 10/20.. Train loss: 0.759.. Valid loss: 0.431.. Valid accuracy: 0.876
# Epoch 10/20.. Train loss: 0.734.. Valid loss: 0.492.. Valid accuracy: 0.863
# Epoch 10/20.. Train loss: 0.779.. Valid loss: 0.499.. Valid accuracy: 0.856
# Epoch 11/20.. Train loss: 0.774.. Valid loss: 0.531.. Valid accuracy: 0.859
# Epoch 11/20.. Train loss: 0.917.. Valid loss: 0.503.. Valid accuracy: 0.851
# Epoch 11/20.. Train loss: 0.802.. Valid loss: 0.522.. Valid accuracy: 0.858
# Epoch 11/20.. Train loss: 0.832.. Valid loss: 0.518.. Valid accuracy: 0.848
# Epoch 11/20.. Train loss: 0.864.. Valid loss: 0.503.. Valid accuracy: 0.858
# Epoch 11/20.. Train loss: 0.574.. Valid loss: 0.554.. Valid accuracy: 0.850
# Epoch 11/20.. Train loss: 0.915.. Valid loss: 0.509.. Valid accuracy: 0.856
# Epoch 11/20.. Train loss: 0.783.. Valid loss: 0.518.. Valid accuracy: 0.841
# Epoch 11/20.. Train loss: 0.790.. Valid loss: 0.587.. Valid accuracy: 0.825
# Epoch 11/20.. Train loss: 0.720.. Valid loss: 0.617.. Valid accuracy: 0.826
# Epoch 11/20.. Train loss: 0.819.. Valid loss: 0.536.. Valid accuracy: 0.848
# Epoch 11/20.. Train loss: 0.732.. Valid loss: 0.522.. Valid accuracy: 0.841
# Epoch 11/20.. Train loss: 0.688.. Valid loss: 0.493.. Valid accuracy: 0.868
# Epoch 11/20.. Train loss: 0.708.. Valid loss: 0.502.. Valid accuracy: 0.864
# Epoch 11/20.. Train loss: 0.640.. Valid loss: 0.480.. Valid accuracy: 0.875
# Epoch 11/20.. Train loss: 0.661.. Valid loss: 0.499.. Valid accuracy: 0.863
# Epoch 11/20.. Train loss: 0.817.. Valid loss: 0.540.. Valid accuracy: 0.854
# Epoch 11/20.. Train loss: 0.788.. Valid loss: 0.534.. Valid accuracy: 0.854
# Epoch 11/20.. Train loss: 0.685.. Valid loss: 0.508.. Valid accuracy: 0.862
# Epoch 11/20.. Train loss: 0.754.. Valid loss: 0.509.. Valid accuracy: 0.850
# Epoch 12/20.. Train loss: 0.753.. Valid loss: 0.493.. Valid accuracy: 0.867
# Epoch 12/20.. Train loss: 0.744.. Valid loss: 0.507.. Valid accuracy: 0.860
# Epoch 12/20.. Train loss: 0.847.. Valid loss: 0.521.. Valid accuracy: 0.852
# Epoch 12/20.. Train loss: 0.791.. Valid loss: 0.475.. Valid accuracy: 0.880
# Epoch 12/20.. Train loss: 0.667.. Valid loss: 0.470.. Valid accuracy: 0.879
# Epoch 12/20.. Train loss: 0.799.. Valid loss: 0.467.. Valid accuracy: 0.869
# Epoch 12/20.. Train loss: 0.835.. Valid loss: 0.520.. Valid accuracy: 0.837
# Epoch 12/20.. Train loss: 0.742.. Valid loss: 0.519.. Valid accuracy: 0.851
# Epoch 12/20.. Train loss: 0.701.. Valid loss: 0.464.. Valid accuracy: 0.866
# Epoch 12/20.. Train loss: 0.659.. Valid loss: 0.440.. Valid accuracy: 0.881
# Epoch 12/20.. Train loss: 0.820.. Valid loss: 0.478.. Valid accuracy: 0.869
# Epoch 12/20.. Train loss: 0.634.. Valid loss: 0.454.. Valid accuracy: 0.866
# Epoch 12/20.. Train loss: 0.744.. Valid loss: 0.462.. Valid accuracy: 0.865
# Epoch 12/20.. Train loss: 0.969.. Valid loss: 0.593.. Valid accuracy: 0.836
# Epoch 12/20.. Train loss: 0.911.. Valid loss: 0.516.. Valid accuracy: 0.857
# Epoch 12/20.. Train loss: 0.739.. Valid loss: 0.508.. Valid accuracy: 0.851
# Epoch 12/20.. Train loss: 0.828.. Valid loss: 0.538.. Valid accuracy: 0.852
# Epoch 12/20.. Train loss: 0.779.. Valid loss: 0.516.. Valid accuracy: 0.859
# Epoch 12/20.. Train loss: 0.826.. Valid loss: 0.523.. Valid accuracy: 0.861
# Epoch 12/20.. Train loss: 0.737.. Valid loss: 0.493.. Valid accuracy: 0.861
# Epoch 12/20.. Train loss: 0.750.. Valid loss: 0.482.. Valid accuracy: 0.864
# Epoch 13/20.. Train loss: 0.700.. Valid loss: 0.488.. Valid accuracy: 0.853
# Epoch 13/20.. Train loss: 0.818.. Valid loss: 0.426.. Valid accuracy: 0.882
# Epoch 13/20.. Train loss: 0.712.. Valid loss: 0.474.. Valid accuracy: 0.882
# Epoch 13/20.. Train loss: 0.654.. Valid loss: 0.479.. Valid accuracy: 0.866
# Epoch 13/20.. Train loss: 0.801.. Valid loss: 0.472.. Valid accuracy: 0.862
# Epoch 13/20.. Train loss: 0.702.. Valid loss: 0.502.. Valid accuracy: 0.860
# Epoch 13/20.. Train loss: 0.748.. Valid loss: 0.503.. Valid accuracy: 0.857
# Epoch 13/20.. Train loss: 0.712.. Valid loss: 0.469.. Valid accuracy: 0.865
# Epoch 13/20.. Train loss: 0.677.. Valid loss: 0.501.. Valid accuracy: 0.843
# Epoch 13/20.. Train loss: 0.941.. Valid loss: 0.464.. Valid accuracy: 0.857
# Epoch 13/20.. Train loss: 0.793.. Valid loss: 0.469.. Valid accuracy: 0.862
# Epoch 13/20.. Train loss: 0.669.. Valid loss: 0.486.. Valid accuracy: 0.866
# Epoch 13/20.. Train loss: 0.708.. Valid loss: 0.504.. Valid accuracy: 0.861
# Epoch 13/20.. Train loss: 0.718.. Valid loss: 0.453.. Valid accuracy: 0.874
# Epoch 13/20.. Train loss: 0.650.. Valid loss: 0.451.. Valid accuracy: 0.873
# Epoch 13/20.. Train loss: 0.817.. Valid loss: 0.428.. Valid accuracy: 0.889
# Epoch 13/20.. Train loss: 0.723.. Valid loss: 0.466.. Valid accuracy: 0.869
# Epoch 13/20.. Train loss: 0.712.. Valid loss: 0.479.. Valid accuracy: 0.857
# Epoch 13/20.. Train loss: 0.917.. Valid loss: 0.474.. Valid accuracy: 0.854
# Epoch 13/20.. Train loss: 0.740.. Valid loss: 0.479.. Valid accuracy: 0.859
# Epoch 14/20.. Train loss: 0.816.. Valid loss: 0.492.. Valid accuracy: 0.865
# Epoch 14/20.. Train loss: 0.741.. Valid loss: 0.535.. Valid accuracy: 0.849
# Epoch 14/20.. Train loss: 0.710.. Valid loss: 0.513.. Valid accuracy: 0.853
# Epoch 14/20.. Train loss: 0.706.. Valid loss: 0.450.. Valid accuracy: 0.873
# Epoch 14/20.. Train loss: 0.600.. Valid loss: 0.450.. Valid accuracy: 0.874
# Epoch 14/20.. Train loss: 0.673.. Valid loss: 0.443.. Valid accuracy: 0.880
# Epoch 14/20.. Train loss: 0.722.. Valid loss: 0.433.. Valid accuracy: 0.884
# Epoch 14/20.. Train loss: 0.748.. Valid loss: 0.439.. Valid accuracy: 0.869
# Epoch 14/20.. Train loss: 0.735.. Valid loss: 0.433.. Valid accuracy: 0.878
# Epoch 14/20.. Train loss: 0.751.. Valid loss: 0.438.. Valid accuracy: 0.880
# Epoch 14/20.. Train loss: 0.651.. Valid loss: 0.422.. Valid accuracy: 0.893
# Epoch 14/20.. Train loss: 0.552.. Valid loss: 0.428.. Valid accuracy: 0.889
# Epoch 14/20.. Train loss: 0.753.. Valid loss: 0.444.. Valid accuracy: 0.887
# Epoch 14/20.. Train loss: 0.635.. Valid loss: 0.427.. Valid accuracy: 0.886
# Epoch 14/20.. Train loss: 0.739.. Valid loss: 0.397.. Valid accuracy: 0.883
# Epoch 14/20.. Train loss: 0.647.. Valid loss: 0.461.. Valid accuracy: 0.880
# Epoch 14/20.. Train loss: 0.765.. Valid loss: 0.455.. Valid accuracy: 0.876
# Epoch 14/20.. Train loss: 0.746.. Valid loss: 0.467.. Valid accuracy: 0.874
# Epoch 14/20.. Train loss: 0.674.. Valid loss: 0.450.. Valid accuracy: 0.873
# Epoch 14/20.. Train loss: 0.701.. Valid loss: 0.424.. Valid accuracy: 0.875
# Epoch 14/20.. Train loss: 0.793.. Valid loss: 0.450.. Valid accuracy: 0.872
# Epoch 15/20.. Train loss: 0.662.. Valid loss: 0.477.. Valid accuracy: 0.859
# Epoch 15/20.. Train loss: 0.759.. Valid loss: 0.438.. Valid accuracy: 0.877
# Epoch 15/20.. Train loss: 0.659.. Valid loss: 0.435.. Valid accuracy: 0.881
# Epoch 15/20.. Train loss: 0.664.. Valid loss: 0.424.. Valid accuracy: 0.886
# Epoch 15/20.. Train loss: 0.684.. Valid loss: 0.396.. Valid accuracy: 0.894
# Epoch 15/20.. Train loss: 0.660.. Valid loss: 0.410.. Valid accuracy: 0.891
# Epoch 15/20.. Train loss: 0.825.. Valid loss: 0.450.. Valid accuracy: 0.871
# Epoch 15/20.. Train loss: 0.585.. Valid loss: 0.443.. Valid accuracy: 0.867
# Epoch 15/20.. Train loss: 0.728.. Valid loss: 0.425.. Valid accuracy: 0.880
# Epoch 15/20.. Train loss: 0.581.. Valid loss: 0.418.. Valid accuracy: 0.884
# Epoch 15/20.. Train loss: 0.615.. Valid loss: 0.412.. Valid accuracy: 0.886
# Epoch 15/20.. Train loss: 0.707.. Valid loss: 0.434.. Valid accuracy: 0.874
# Epoch 15/20.. Train loss: 0.605.. Valid loss: 0.420.. Valid accuracy: 0.883
# Epoch 15/20.. Train loss: 0.580.. Valid loss: 0.415.. Valid accuracy: 0.882
# Epoch 15/20.. Train loss: 0.698.. Valid loss: 0.414.. Valid accuracy: 0.881
# Epoch 15/20.. Train loss: 0.583.. Valid loss: 0.409.. Valid accuracy: 0.878
# Epoch 15/20.. Train loss: 0.622.. Valid loss: 0.431.. Valid accuracy: 0.879
# Epoch 15/20.. Train loss: 0.677.. Valid loss: 0.440.. Valid accuracy: 0.886
# Epoch 15/20.. Train loss: 0.769.. Valid loss: 0.422.. Valid accuracy: 0.880
# Epoch 15/20.. Train loss: 0.818.. Valid loss: 0.466.. Valid accuracy: 0.871
# Epoch 15/20.. Train loss: 0.775.. Valid loss: 0.464.. Valid accuracy: 0.860
# Epoch 16/20.. Train loss: 0.602.. Valid loss: 0.483.. Valid accuracy: 0.865
# Epoch 16/20.. Train loss: 0.683.. Valid loss: 0.453.. Valid accuracy: 0.879
# Epoch 16/20.. Train loss: 0.609.. Valid loss: 0.419.. Valid accuracy: 0.892
# Epoch 16/20.. Train loss: 0.639.. Valid loss: 0.422.. Valid accuracy: 0.890
# Epoch 16/20.. Train loss: 0.784.. Valid loss: 0.386.. Valid accuracy: 0.890
# Epoch 16/20.. Train loss: 0.557.. Valid loss: 0.410.. Valid accuracy: 0.879
# Epoch 16/20.. Train loss: 0.660.. Valid loss: 0.470.. Valid accuracy: 0.862
# Epoch 16/20.. Train loss: 0.676.. Valid loss: 0.433.. Valid accuracy: 0.873
# Epoch 16/20.. Train loss: 0.529.. Valid loss: 0.423.. Valid accuracy: 0.883
# Epoch 16/20.. Train loss: 0.586.. Valid loss: 0.416.. Valid accuracy: 0.885
# Epoch 16/20.. Train loss: 0.729.. Valid loss: 0.391.. Valid accuracy: 0.896
# Epoch 16/20.. Train loss: 0.713.. Valid loss: 0.405.. Valid accuracy: 0.888
# Epoch 16/20.. Train loss: 0.612.. Valid loss: 0.422.. Valid accuracy: 0.887
# Epoch 16/20.. Train loss: 0.704.. Valid loss: 0.447.. Valid accuracy: 0.868
# Epoch 16/20.. Train loss: 0.651.. Valid loss: 0.427.. Valid accuracy: 0.880
# Epoch 16/20.. Train loss: 0.721.. Valid loss: 0.443.. Valid accuracy: 0.876
# Epoch 16/20.. Train loss: 0.651.. Valid loss: 0.473.. Valid accuracy: 0.870
# Epoch 16/20.. Train loss: 0.677.. Valid loss: 0.472.. Valid accuracy: 0.859
# Epoch 16/20.. Train loss: 0.636.. Valid loss: 0.447.. Valid accuracy: 0.872
# Epoch 16/20.. Train loss: 0.781.. Valid loss: 0.378.. Valid accuracy: 0.884
# Epoch 17/20.. Train loss: 0.604.. Valid loss: 0.449.. Valid accuracy: 0.871
# Epoch 17/20.. Train loss: 0.802.. Valid loss: 0.429.. Valid accuracy: 0.881
# Epoch 17/20.. Train loss: 0.572.. Valid loss: 0.459.. Valid accuracy: 0.864
# Epoch 17/20.. Train loss: 0.639.. Valid loss: 0.435.. Valid accuracy: 0.880
# Epoch 17/20.. Train loss: 0.791.. Valid loss: 0.412.. Valid accuracy: 0.884
# Epoch 17/20.. Train loss: 0.717.. Valid loss: 0.475.. Valid accuracy: 0.876
# Epoch 17/20.. Train loss: 0.754.. Valid loss: 0.424.. Valid accuracy: 0.882
# Epoch 17/20.. Train loss: 0.609.. Valid loss: 0.427.. Valid accuracy: 0.881
# Epoch 17/20.. Train loss: 0.779.. Valid loss: 0.392.. Valid accuracy: 0.882
# Epoch 17/20.. Train loss: 0.650.. Valid loss: 0.424.. Valid accuracy: 0.870
# Epoch 17/20.. Train loss: 0.600.. Valid loss: 0.419.. Valid accuracy: 0.876
# Epoch 17/20.. Train loss: 0.668.. Valid loss: 0.420.. Valid accuracy: 0.887
# Epoch 17/20.. Train loss: 0.636.. Valid loss: 0.444.. Valid accuracy: 0.879
# Epoch 17/20.. Train loss: 0.835.. Valid loss: 0.435.. Valid accuracy: 0.882
# Epoch 17/20.. Train loss: 0.691.. Valid loss: 0.405.. Valid accuracy: 0.885
# Epoch 17/20.. Train loss: 0.693.. Valid loss: 0.411.. Valid accuracy: 0.886
# Epoch 17/20.. Train loss: 0.584.. Valid loss: 0.418.. Valid accuracy: 0.885
# Epoch 17/20.. Train loss: 0.553.. Valid loss: 0.449.. Valid accuracy: 0.871
# Epoch 17/20.. Train loss: 0.612.. Valid loss: 0.453.. Valid accuracy: 0.877
# Epoch 17/20.. Train loss: 0.702.. Valid loss: 0.456.. Valid accuracy: 0.873
# Epoch 17/20.. Train loss: 0.793.. Valid loss: 0.458.. Valid accuracy: 0.874
# Epoch 18/20.. Train loss: 0.618.. Valid loss: 0.483.. Valid accuracy: 0.871
# Epoch 18/20.. Train loss: 0.654.. Valid loss: 0.428.. Valid accuracy: 0.885
# Epoch 18/20.. Train loss: 0.780.. Valid loss: 0.424.. Valid accuracy: 0.896
# Epoch 18/20.. Train loss: 0.637.. Valid loss: 0.414.. Valid accuracy: 0.895
# Epoch 18/20.. Train loss: 0.700.. Valid loss: 0.411.. Valid accuracy: 0.896
# Epoch 18/20.. Train loss: 0.608.. Valid loss: 0.413.. Valid accuracy: 0.880
# Epoch 18/20.. Train loss: 0.685.. Valid loss: 0.398.. Valid accuracy: 0.885
# Epoch 18/20.. Train loss: 0.481.. Valid loss: 0.426.. Valid accuracy: 0.881
# Epoch 18/20.. Train loss: 0.605.. Valid loss: 0.421.. Valid accuracy: 0.880
# Epoch 18/20.. Train loss: 0.755.. Valid loss: 0.406.. Valid accuracy: 0.892
# Epoch 18/20.. Train loss: 0.664.. Valid loss: 0.409.. Valid accuracy: 0.896
# Epoch 18/20.. Train loss: 0.594.. Valid loss: 0.402.. Valid accuracy: 0.886
# Epoch 18/20.. Train loss: 0.630.. Valid loss: 0.420.. Valid accuracy: 0.889
# Epoch 18/20.. Train loss: 0.638.. Valid loss: 0.473.. Valid accuracy: 0.866
# Epoch 18/20.. Train loss: 0.632.. Valid loss: 0.432.. Valid accuracy: 0.883
# Epoch 18/20.. Train loss: 0.680.. Valid loss: 0.420.. Valid accuracy: 0.881
# Epoch 18/20.. Train loss: 0.694.. Valid loss: 0.385.. Valid accuracy: 0.894
# Epoch 18/20.. Train loss: 0.685.. Valid loss: 0.406.. Valid accuracy: 0.888
# Epoch 18/20.. Train loss: 0.624.. Valid loss: 0.406.. Valid accuracy: 0.894
# Epoch 18/20.. Train loss: 0.676.. Valid loss: 0.436.. Valid accuracy: 0.879
# Epoch 19/20.. Train loss: 0.728.. Valid loss: 0.456.. Valid accuracy: 0.864
# Epoch 19/20.. Train loss: 0.673.. Valid loss: 0.422.. Valid accuracy: 0.873
# Epoch 19/20.. Train loss: 0.676.. Valid loss: 0.407.. Valid accuracy: 0.879
# Epoch 19/20.. Train loss: 0.530.. Valid loss: 0.434.. Valid accuracy: 0.879
# Epoch 19/20.. Train loss: 0.687.. Valid loss: 0.406.. Valid accuracy: 0.889
# Epoch 19/20.. Train loss: 0.677.. Valid loss: 0.381.. Valid accuracy: 0.901
# Epoch 19/20.. Train loss: 0.585.. Valid loss: 0.383.. Valid accuracy: 0.894
# Epoch 19/20.. Train loss: 0.701.. Valid loss: 0.394.. Valid accuracy: 0.898
# Epoch 19/20.. Train loss: 0.553.. Valid loss: 0.426.. Valid accuracy: 0.883
# Epoch 19/20.. Train loss: 0.700.. Valid loss: 0.433.. Valid accuracy: 0.871
# Epoch 19/20.. Train loss: 0.759.. Valid loss: 0.391.. Valid accuracy: 0.884
# Epoch 19/20.. Train loss: 0.633.. Valid loss: 0.426.. Valid accuracy: 0.878
# Epoch 19/20.. Train loss: 0.642.. Valid loss: 0.391.. Valid accuracy: 0.905
# Epoch 19/20.. Train loss: 0.651.. Valid loss: 0.406.. Valid accuracy: 0.898
# Epoch 19/20.. Train loss: 0.746.. Valid loss: 0.373.. Valid accuracy: 0.903
# Epoch 19/20.. Train loss: 0.688.. Valid loss: 0.360.. Valid accuracy: 0.904
# Epoch 19/20.. Train loss: 0.588.. Valid loss: 0.403.. Valid accuracy: 0.884
# Epoch 19/20.. Train loss: 0.745.. Valid loss: 0.406.. Valid accuracy: 0.885
# Epoch 19/20.. Train loss: 0.604.. Valid loss: 0.412.. Valid accuracy: 0.883
# Epoch 19/20.. Train loss: 0.707.. Valid loss: 0.400.. Valid accuracy: 0.893
# Epoch 19/20.. Train loss: 0.664.. Valid loss: 0.407.. Valid accuracy: 0.891
# Epoch 20/20.. Train loss: 0.807.. Valid loss: 0.454.. Valid accuracy: 0.876
# Epoch 20/20.. Train loss: 0.738.. Valid loss: 0.385.. Valid accuracy: 0.903
# Epoch 20/20.. Train loss: 0.663.. Valid loss: 0.451.. Valid accuracy: 0.881
# Epoch 20/20.. Train loss: 0.565.. Valid loss: 0.451.. Valid accuracy: 0.872
# Epoch 20/20.. Train loss: 0.623.. Valid loss: 0.407.. Valid accuracy: 0.869
# Epoch 20/20.. Train loss: 0.587.. Valid loss: 0.414.. Valid accuracy: 0.877
# Epoch 20/20.. Train loss: 0.738.. Valid loss: 0.367.. Valid accuracy: 0.889
# Epoch 20/20.. Train loss: 0.643.. Valid loss: 0.365.. Valid accuracy: 0.882
# Epoch 20/20.. Train loss: 0.636.. Valid loss: 0.413.. Valid accuracy: 0.881
# Epoch 20/20.. Train loss: 0.629.. Valid loss: 0.413.. Valid accuracy: 0.885
# Epoch 20/20.. Train loss: 0.562.. Valid loss: 0.402.. Valid accuracy: 0.893
# Epoch 20/20.. Train loss: 0.592.. Valid loss: 0.414.. Valid accuracy: 0.883
# Epoch 20/20.. Train loss: 0.724.. Valid loss: 0.386.. Valid accuracy: 0.892
# Epoch 20/20.. Train loss: 0.565.. Valid loss: 0.363.. Valid accuracy: 0.893
# Epoch 20/20.. Train loss: 0.602.. Valid loss: 0.385.. Valid accuracy: 0.885
# Epoch 20/20.. Train loss: 0.562.. Valid loss: 0.395.. Valid accuracy: 0.887
# Epoch 20/20.. Train loss: 0.534.. Valid loss: 0.433.. Valid accuracy: 0.878
# Epoch 20/20.. Train loss: 0.728.. Valid loss: 0.408.. Valid accuracy: 0.876
# Epoch 20/20.. Train loss: 0.655.. Valid loss: 0.432.. Valid accuracy: 0.879
# Epoch 20/20.. Train loss: 0.767.. Valid loss: 0.431.. Valid accuracy: 0.868
# Epoch 20/20.. Train loss: 0.748.. Valid loss: 0.438.. Valid accuracy: 0.883

# %% [markdown]
# ## Testing your network
#
# It's good practice to test your trained network on test data, images the network has never seen either in training or validation. This will give you a good estimate for the model's performance on completely new images. Run the test images through the network and measure the accuracy, the same way you did validation. You should be able to reach around 70% accuracy on the test set if the model has been trained well.

# %%
# TODO: Do validation on the test set
def check_accuracy_on_test(testloader):    
    correct = 0
    total = 0
    model.to('cuda:0')
    with torch.no_grad():
        for data in testloader:
            images, labels = data
            images, labels = images.to('cuda'), labels.to('cuda')
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    print('Accuracy of the network on the test images: %d %%' % (100 * correct / total))
    
check_accuracy_on_test(testloader)
# Out:
# Accuracy of the network on the test images: 84 %

# %%
plt.plot(range(len(train_losses)), train_losses, valid_losses)
# Out:
# [<matplotlib.lines.Line2D at 0x7f68ac5582e8>,
#  <matplotlib.lines.Line2D at 0x7f68ac558a20>]

# %% [markdown]
# ## Save the checkpoint
#
# Now that your network is trained, save the model so you can load it later for making predictions. You probably want to save other things such as the mapping of classes to indices which you get from one of the image datasets: `image_datasets['train'].class_to_idx`. You can attach this to the model as an attribute which makes inference easier later on.
#
# ```model.class_to_idx = image_datasets['train'].class_to_idx```
#
# Remember that you'll want to completely rebuild the model later so you can use it for inference. Make sure to include any information you need in the checkpoint. If you want to load the model and keep training, you'll want to save the number of epochs as well as the optimizer state, `optimizer.state_dict`. You'll likely want to use this trained model in the next part of the project, so best to save it now.

# %%
# TODO: Save the checkpoint 

model.class_to_idx = train_data.class_to_idx
model.cpu
torch.save({'structure' :'vgg16',
            'hidden_layer1':120,
            'state_dict':model.state_dict(),
            'class_to_idx':model.class_to_idx},
            'checkpoint.pth')

# %% [markdown]
# ## Loading the checkpoint
#
# At this point it's good to write a function that can load a checkpoint and rebuild the model. That way you can come back to this project and keep working on it without having to retrain the network.

# %%
# TODO: Write a function that loads a checkpoint and rebuilds the model
def load_model(path):
    checkpoint = torch.load('checkpoint.pth')
    structure = checkpoint['structure']
    hidden_layer1 = checkpoint['hidden_layer1']
    model,_,_ = nn_setup(structure , 0.5,hidden_layer1)
    model.class_to_idx = checkpoint['class_to_idx']
    model.load_state_dict(checkpoint['state_dict'])
    
    
load_model('checkpoint.pth')

# %% [markdown]
# # Inference for classification
#
# Now you'll write a function to use a trained network for inference. That is, you'll pass an image into the network and predict the class of the flower in the image. Write a function called `predict` that takes an image and a model, then returns the top $K$ most likely classes along with the probabilities. It should look like
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# First you'll need to handle processing the input image such that it can be used in your network.
#
# ## Image Preprocessing
#
# You'll want to use `PIL` to load the image ([documentation](https://pillow.readthedocs.io/en/latest/reference/Image.html)). It's best to write a function that preprocesses the image so it can be used as input for the model. This function should process the images in the same manner used for training.
#
# First, resize the images where the shortest side is 256 pixels, keeping the aspect ratio. This can be done with the [`thumbnail`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) or [`resize`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) methods. Then you'll need to crop out the center 224x224 portion of the image.
#
# Color channels of images are typically encoded as integers 0-255, but the model expected floats 0-1. You'll need to convert the values. It's easiest with a Numpy array, which you can get from a PIL image like so `np_image = np.array(pil_image)`.
#
# As before, the network expects the images to be normalized in a specific way. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`. You'll want to subtract the means from each color channel, then divide by the standard deviation.
#
# And finally, PyTorch expects the color channel to be the first dimension but it's the third dimension in the PIL image and Numpy array. You can reorder dimensions using [`ndarray.transpose`](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.ndarray.transpose.html). The color channel needs to be first and retain the order of the other two dimensions.

# %%
def process_image(image):
    img = Image.open(image)
   
    adjustments = transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])
    
    img_tensor = adjustments(img)
    
    return img_tensor
    
    
    # TODO: Process a PIL image for use in a PyTorch model

img_path = (data_dir + '/test' + '/1/' + 'image_06752.jpg')
PIL_img = process_image(img_path)

# %% [markdown]
# To check your work, the function below converts a PyTorch tensor and displays it in the notebook. If your `process_image` function works, running the output through this function should return the original image (except for the cropped out portions).

# %%
def imshow(image, ax=None, title=None):
    """Imshow for Tensor."""
    if ax is None:
        fig, ax = plt.subplots()
    
    # PyTorch tensors assume the color channel is the first dimension
    # but matplotlib assumes is the third dimension
    image = image.numpy().transpose((1, 2, 0))
    
    # Undo preprocessing
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean
    
    # Image needs to be clipped between 0 and 1 or it looks like noise when displayed
    image = np.clip(image, 0, 1)
    
    ax.imshow(image)
    
    return ax

# %% [markdown]
# ## Class Prediction
#
# Once you can get images in the correct format, it's time to write a function for making predictions with your model. A common practice is to predict the top 5 or so (usually called top-$K$) most probable classes. You'll want to calculate the class probabilities then find the $K$ largest values.
#
# To get the top $K$ largest values in a tensor use [`x.topk(k)`](http://pytorch.org/docs/master/torch.html#torch.topk). This method returns both the highest `k` probabilities and the indices of those probabilities corresponding to the classes. You need to convert from these indices to the actual class labels using `class_to_idx` which hopefully you added to the model or from an `ImageFolder` you used to load the data ([see here](#Save-the-checkpoint)). Make sure to invert the dictionary so you get a mapping from index to class as well.
#
# Again, this method should take a path to an image and a model checkpoint, then return the probabilities and classes.
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```

# %%
model.class_to_idx =train_data.class_to_idx

ctx = model.class_to_idx


def predict(image_path, model, topk=5):   
    model.to('cuda:0')
    img_torch = process_image(image_path)
    img_torch = img_torch.unsqueeze_(0)
    img_torch = img_torch.float()
    
    with torch.no_grad():
        output = model.forward(img_torch.cuda())
        
    probability = F.softmax(output.data,dim=1)
    
    return probability.topk(topk)
    
    # TODO: Implement the code to predict the class from an image file

# %%
img = (data_dir + '/test' + '/10/' + 'image_07104.jpg')
prob, fl_class = predict(img, model)
print(prob)
print(fl_class)
# Out:
# tensor([[ 9.4648e-01,  5.3496e-02,  9.2458e-06,  5.5185e-06,  4.8005e-06]], device='cuda:0')
# tensor([[  1,   8,  34,  24,  31]], device='cuda:0')

# %% [markdown]
# ## Sanity Checking
#
# Now that you can use a trained model for predictions, check to make sure it makes sense. Even if the testing accuracy is high, it's always good to check that there aren't obvious bugs. Use `matplotlib` to plot the probabilities for the top 5 classes as a bar graph, along with the input image. It should look like this:
#
# <img src='assets/inference_example.png' width=300px>
#
# You can convert from the class integer encoding to actual flower names with the `cat_to_name.json` file (should have been loaded earlier in the notebook). To show a PyTorch tensor as an image, use the `imshow` function defined above.

# %%
# TODO: Display an image along with the top 5 classes
def check_sanity():
    plt.rcParams["figure.figsize"] = (15,8)
    plt.subplot(211)
    
    index = 1
    path = test_dir + '/1/image_06743.jpg'

    probabilities = predict(path, model)
    image = process_image(path)    

    axs = imshow(image, ax = plt)
    axs.axis('off')
    axs.title(cat_to_name[str(index)])
    axs.show()
    
    a = np.array(probabilities[0][0])
    b = [cat_to_name[str(index + 1)] for index in np.array(probabilities[1][0])]
    
    
    N=float(len(b))
    fig,ax = plt.subplots(figsize=(8,3))
    width = 0.8
    tickLocations = np.arange(N)
    ax.bar(tickLocations, a, width, linewidth=4.0, align = 'center')
    ax.set_xticks(ticks = tickLocations)
    ax.set_xticklabels(b)
    ax.set_xlim(min(tickLocations)-0.6,max(tickLocations)+0.6)
    ax.set_yticks([0.2,0.4,0.6,0.8,1,1.2])
    ax.set_ylim((0,1))
    ax.yaxis.grid(True)
    ax.yaxis.set_major_formatter(FormatStrFormatter('%.2f'))

    plt.show()

# %%
check_sanity()
